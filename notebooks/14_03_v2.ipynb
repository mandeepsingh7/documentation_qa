# %%
import sys 
import os 
sys.path.append(os.path.abspath(".."))
from src.query import get_final_response

# %%
pls_work = get_final_response('When can cudaGetDriverEntryPoint return a NULL function pointer even if the API call returns cudaSuccess?')
# Out:
# 133
# 1
# ['https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html', 'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html', 'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html', 'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html', 'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html']

# %%
pls_work
# Out:
# {'response': 'The API will return cudaSuccess and set the returned funcPtr to NULL if the requested driver function is not supported on the platform, or if no ABI compatible driver function exists for the requested driver symbol.',
#  'urls': ['https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html',
#   'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html',
#   'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html',
#   'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html',
#   'https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html']}
